# %% [markdown]
# <a href="https://colab.research.google.com/github/RandomThings4/python-data-learning/blob/main/week1_2026_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-837d6b69-c5d5-47e6-829a-82dfa7c91115" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-837d6b69-c5d5-47e6-829a-82dfa7c91115">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
skittle = pd.read_csv("Skittle Struggle  - Sheet1.csv")
skittle = skittle.drop(columns=['Unnamed: 4'])
skittle.head()
print("Number of rows:", skittle.shape[0])
print("Number of columns:", skittle.shape[1])
print("Correct Guesses Total:", skittle["Correct Guesses"].sum())
print("Wrong Guesses Total:", skittle["Wrong Guesses"].sum())
# Out:
# Number of rows: 6
# Number of columns: 4
# Columns:
# ['Color', 'Correct Guesses', 'Wrong Guesses', 'Guess Percentage']
# Correct Guesses Total: 120
# Wrong Guesses Total: 172

# %%
display(skittle)
# Out:
#               Color  Correct Guesses  Wrong Guesses Guess Percentage
# 0  Red (Strawberry)               14             17           45.16%
# 1   Orange (Orange)               10             21           32.26%
# 2    Yellow (Lemon)               13             15           46.43%
# 3      Green (Lime)               11             19           36.67%
# 4    Purple (Grape)               12             14           46.15%
# 5               All               60             86           40.54%
